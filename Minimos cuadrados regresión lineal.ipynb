# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
1545.2
n = int(input("ingrese la cantidad de elementos"))

listaX=[]

for i in range(n):
  listaX.append(float(input("Ingrese numero: ")))

  print(listaX)

print("Ingresa lista para Y")
print(" ")
print(" ")

listaY=[]

for i in range(n):
  listaY.append(float(input("Ingrese numero: ")))

  print(listaY)
# Out:
# ingrese la cantidad de elementos5
# Ingrese numero: 1
# [1.0]
# Ingrese numero: 1.6
# [1.0, 1.6]
# Ingrese numero: 3.4
# [1.0, 1.6, 3.4]
# Ingrese numero: 4
# [1.0, 1.6, 3.4, 4.0]
# Ingrese numero: 5.2
# [1.0, 1.6, 3.4, 4.0, 5.2]
# Ingresa lista para Y
#
#
# Ingrese numero: 1.2
# [1.2]
# Ingrese numero: 2
# [1.2, 2.0]
# Ingrese numero: 2.4
# [1.2, 2.0, 2.4]
# Ingrese numero: 3.5
# [1.2, 2.0, 2.4, 3.5]
# Ingrese numero: 3.5
# [1.2, 2.0, 2.4, 3.5, 3.5]

# %%
sumalistaX = sum(listaX)
sumalistaY = sum(listaY)

r_xy = np.multiply(listaX,listaY)
suma_xy=sum(r_xy)
cuadrado = np.multiply(listaX,listaX)
cuad=sum(cuadrado)


print("La sumatoria de los elementos de X es: ", sumalistaX)
print("La sumatoria de los elementos de Y es: ", sumalistaY)
print("La sumatoria de la multiplicacion de ambos es: ", suma_xy)
print("Sumaroria de xi al cuadrado es: ", cuad)
# Out:
# La sumatoria de los elementos de X es:  15.2
# La sumatoria de los elementos de Y es:  12.6
# La sumatoria de la multiplicacion de ambos es:  44.760000000000005
# Sumaroria de xi al cuadrado es:  58.16

# %%
parteAbajoA = (n*cuad) - (np.multiply(sumalistaX,sumalistaX))
parteArribaA = (n*suma_xy) - (sumalistaX*sumalistaY)

a = parteArribaA/parteAbajoA

print("valor de a: ", a)


parteAbajoB = (n*cuad) - (np.multiply(sumalistaX,sumalistaX))
parteArribaB = (sumalistaY*cuad) - (suma_xy*sumalistaX)

b = parteArribaB/parteAbajoB


print("valor de b: ", b)
# Out:
# valor de a:  0.540160642570282
# valor de b:  0.877911646586343

# %%
def mult(b, listaX):
    return [a + (b *  listaX[i]) for i in range(len(listaX))]

print(mult(b, listaX))



plt.scatter(listaX,listaY)
plt.plot(listaX,mult(b, listaX))
plt.show()
# Out:
# [1.4180722891566249, 1.9448192771084307, 3.5250602409638483, 4.051807228915654, 5.105301204819265]
